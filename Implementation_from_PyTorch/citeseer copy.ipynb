# %%
import torch
import torch_geometric
import numpy as np

# %% [markdown]
# ## Loading Dataset

# %%
from torch_geometric.datasets import Planetoid

dataset = Planetoid(root = 'Citeseer', name = 'Citeseer')

# %%
data = dataset[0]
print(dataset)
print(data)
print("number of graphs:\t\t",len(dataset))
print("number of classes:\t\t",dataset.num_classes)
print("number of classes:\t\t",np.unique(data.y))
print(f"Number of nodes:\t\t",data.num_nodes)
print("number of node features:\t",data.num_node_features)
print("number of edge features:\t",data.num_edge_features)
print("X shape: ", data.x.shape)
print("Edge shape: ", data.edge_index.shape)
print("Y shape: ", data.y.shape)
# Out:
# Citeseer()
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# number of graphs:		 1
# number of classes:		 6
# number of classes:		 [0 1 2 3 4 5]
# Number of nodes:		 3327
# number of node features:	 3703
# number of edge features:	 0
# X shape:  torch.Size([3327, 3703])
# Edge shape:  torch.Size([2, 9104])
# Y shape:  torch.Size([3327])

# %% [markdown]
# train mask is a binary mask (a tensor or array of True/False or 1/0 values) that indicates which nodes in the graph should be used during training.

# %% [markdown]
# ## EDA

# %%
import networkx as nx
import matplotlib.pyplot as plt
def visualize_graph(edge_index, labels, num_nodes):
    G = nx.Graph()
    edge_list = edge_index.t().tolist()  
    G.add_edges_from(edge_list)
    G.add_nodes_from(range(num_nodes)) 

    # Ensure labels match number of nodes
    labels = labels[:num_nodes]  # Truncate extra labels if necessary

    # Generate positions for the graph
    pos = nx.spring_layout(G, seed=42)  # Use spring layout for visualization

    plt.figure(figsize=(12, 8))
    nx.draw(
        G,
        pos,
        with_labels=False,
        node_color=labels,
        cmap=plt.cm.rainbow,
        node_size=50,
    )
    plt.title("Citeseer Graph Structure")
    plt.show()

# %%
# visualize_graph(data.edge_index, data.y.numpy(), data.num_nodes)

# %%
print(data.edge_index)
# Out:
# tensor([[ 628,  158,  486,  ..., 2820, 1643,   33],
#         [   0,    1,    1,  ..., 3324, 3325, 3326]])

# %% [markdown]
# ## Model Training

# %% [markdown]
# $$
# H^{(l+1)} = \sigma\left(\widehat{A} H^{(l)} W^{(l)}\right)
# $$

# %% [markdown]
# $$
# \widehat{A} = \widetilde{D}^{-1/2} \widetilde{A} \widetilde{D}^{-1/2}
# $$

# %%
class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = torch_geometric.nn.GCNConv(dataset.num_node_features, 16)
        self.conv2 = torch_geometric.nn.GCNConv(16, dataset.num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = torch.nn.functional.relu(self.conv1(x, edge_index))
        x = torch.nn.functional.dropout(x, training= self.training)

        x = torch.nn.functional.log_softmax(self.conv2(x, edge_index), dim= 1)

        return x

# %%
def train(model, data, optimizer, criterion, train_mask):
    model.train()
    optimizer.zero_grad()
    out = model(data)
    loss = criterion(out[data.train_mask], data.y[train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()

def test(model, data, mask):
    model.eval()
    with torch.no_grad():
        pred1 = model(data)
        pred = pred1.argmax(dim = 1)
        correct = (pred[mask] == data.y[mask]).sum()
        acc = int(correct) / int(mask.sum())
    return acc

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN().to(device)
data = data.to(device)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.NLLLoss()
# Out:
# GCN(
#   (conv1): GCNConv(3703, 16)
#   (conv2): GCNConv(16, 6)
# )

# %%
for epoch in range(200):
    loss = train(model, data, optimizer, criterion, data.train_mask)
    train_acc = test(model, data, data.train_mask)
    val_acc = test(model, data, data.val_mask)
    print(f'Epoch {epoch+1}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}')

    if val_acc >0.6500:
        break


# Does each time data changes??

model.eval()
with torch.no_grad():
    pred1 = model(data)
    pred = pred1.argmax(dim=1) 
    correct = (pred[data.test_mask] == data.y[data.test_mask]).sum() 
    acc = int(correct) / int(data.test_mask.sum())
    # f1 = f1_score(pred[data.test_mask].cpu(), data.y[data.test_mask].cpu(), average='macro') 
    print(f'Accuracy: {acc:.4f}') # ,f'F1_score: {f1:.4f}'
# Out:
# Epoch 1, Loss: 1.7936, Train Acc: 0.6250, Val Acc: 0.4220
# Epoch 2, Loss: 1.6210, Train Acc: 0.7000, Val Acc: 0.4480
# Epoch 3, Loss: 1.4151, Train Acc: 0.7417, Val Acc: 0.4660
# Epoch 4, Loss: 1.2427, Train Acc: 0.7833, Val Acc: 0.4680
# Epoch 5, Loss: 1.0864, Train Acc: 0.8417, Val Acc: 0.4960
# Epoch 6, Loss: 0.9388, Train Acc: 0.9000, Val Acc: 0.5160
# Epoch 7, Loss: 0.7937, Train Acc: 0.9250, Val Acc: 0.5660
# Epoch 8, Loss: 0.7215, Train Acc: 0.9500, Val Acc: 0.5800
# Epoch 9, Loss: 0.6519, Train Acc: 0.9583, Val Acc: 0.5880
# Epoch 10, Loss: 0.5484, Train Acc: 0.9667, Val Acc: 0.6060
# Epoch 11, Loss: 0.4772, Train Acc: 0.9667, Val Acc: 0.6060
# Epoch 12, Loss: 0.4457, Train Acc: 0.9667, Val Acc: 0.6100
# Epoch 13, Loss: 0.3863, Train Acc: 0.9917, Val Acc: 0.6120
# Epoch 14, Loss: 0.3552, Train Acc: 1.0000, Val Acc: 0.6180
# Epoch 15, Loss: 0.2994, Train Acc: 1.0000, Val Acc: 0.6200
# Epoch 16, Loss: 0.2632, Train Acc: 1.0000, Val Acc: 0.6200
# Epoch 17, Loss: 0.2312, Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 18, Loss: 0.2412, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 19, Loss: 0.1846, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 20, Loss: 0.1618, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 21, Loss: 0.1524, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 22, Loss: 0.1639, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 23, Loss: 0.1304, Train Acc: 1.0000, Val Acc: 0.6440
# Epoch 24, Loss: 0.0957, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 25, Loss: 0.1046, Train Acc: 1.0000, Val Acc: 0.6440
# Epoch 26, Loss: 0.1343, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 27, Loss: 0.0807, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 28, Loss: 0.0699, Train Acc: 1.0000, Val Acc: 0.6440
# Epoch 29, Loss: 0.0803, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 30, Loss: 0.0821, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 31, Loss: 0.1010, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 32, Loss: 0.0954, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 33, Loss: 0.0663, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 34, Loss: 0.0580, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 35, Loss: 0.0451, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 36, Loss: 0.0524, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 37, Loss: 0.0438, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 38, Loss: 0.0454, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 39, Loss: 0.0339, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 40, Loss: 0.0513, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 41, Loss: 0.0906, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 42, Loss: 0.0315, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 43, Loss: 0.0877, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 44, Loss: 0.0457, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 45, Loss: 0.0364, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 46, Loss: 0.0540, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 47, Loss: 0.0380, Train Acc: 1.0000, Val Acc: 0.6400
# Epoch 48, Loss: 0.0449, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 49, Loss: 0.0371, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 50, Loss: 0.0468, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch
Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 143, Loss: 0.0213, Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 144, Loss: 0.0128, Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 145, Loss: 0.0229, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 146, Loss: 0.0064, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 147, Loss: 0.0141, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 148, Loss: 0.0161, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 149, Loss: 0.0058, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 150, Loss: 0.0250, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 151, Loss: 0.0382, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 152, Loss: 0.0092, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 153, Loss: 0.0042, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 154, Loss: 0.0108, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 155, Loss: 0.0035, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 156, Loss: 0.0047, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 157, Loss: 0.0064, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 158, Loss: 0.0041, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 159, Loss: 0.0032, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 160, Loss: 0.0056, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 161, Loss: 0.0181, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 162, Loss: 0.0076, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 163, Loss: 0.0280, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 164, Loss: 0.0138, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 165, Loss: 0.0064, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 166, Loss: 0.0084, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 167, Loss: 0.0131, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 168, Loss: 0.0173, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 169, Loss: 0.0066, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 170, Loss: 0.0070, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 171, Loss: 0.0111, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 172, Loss: 0.0121, Train Acc: 1.0000, Val Acc: 0.6380
# Epoch 173, Loss: 0.0037, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 174, Loss: 0.0056, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 175, Loss: 0.0084, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 176, Loss: 0.0197, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 177, Loss: 0.0081, Train Acc: 1.0000, Val Acc: 0.6340
# Epoch 178, Loss: 0.0201, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 179, Loss: 0.0037, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 180, Loss: 0.0047, Train Acc: 1.0000, Val Acc: 0.6260
# Epoch 181, Loss: 0.0335, Train Acc: 1.0000, Val Acc: 0.6240
# Epoch 182, Loss: 0.0212, Train Acc: 1.0000, Val Acc: 0.6260
# Epoch 183, Loss: 0.0058, Train Acc: 1.0000, Val Acc: 0.6260
# Epoch 184, Loss: 0.0053, Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 185, Loss: 0.0279, Train Acc: 1.0000, Val Acc: 0.6300
# Epoch 186, Loss: 0.0061, Train Acc: 1.0000, Val Acc: 0.6280
# Epoch 187, Loss: 0.0076, Train Acc: 1.0000, Val Acc: 0.6320
# Epoch 188, Loss: 0.0087, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 189, Loss: 0.0043, Train Acc: 1.0000, Val Acc: 0.6360
# Epoch 190, Loss: 0.0101, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 191, Loss: 0.0121, Train Acc: 1.0000, Val Acc: 0.6420
# Epoch 192, Loss: 0.0305, Train Acc: 1.0000, Val Acc: 0.6440
# Epoch 193, Loss: 0.0662, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 194, Loss: 0.0030, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 195, Loss: 0.0038, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 196, Loss: 0.0079, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 197, Loss: 0.0066, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 198, Loss: 0.0052, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 199, Loss: 0.0257, Train Acc: 1.0000, Val Acc: 0.6460
# Epoch 200, Loss: 0.0233, Train Acc: 1.0000, Val Acc: 0.6440

# %%
def visualize_features(features, title="Node Features"):
    plt.figure(figsize=(12, 6))
    plt.imshow(features, aspect='auto', cmap='coolwarm')
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Feature Dimension")
    plt.ylabel("Node Index")
    plt.show()

# visualize_features(data.x.numpy(), title="Original Node Features")

# Forward pass visualization
model = GCN(data.num_features, 16, dataset.num_classes)
with torch.no_grad():
    x = data.x
    visualize_features(x.numpy(), title="Input Features to Layer 1")
    x = model.gcn1(x, data.edge_index)
    visualize_features(x.numpy(), title="Output of GCN Layer 1")
    x = model.gcn2(x, data.edge_index)
    visualize_features(x.numpy(), title="Output of GCN Layer 2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 13
#       8     plt.show()
#      10 # visualize_features(data.x.numpy(), title="Original Node Features")
#      11
#      12 # Forward pass visualization
# ---> 13 model = GCN(data.num_features, 16, dataset.num_classes)
#      14 with torch.no_grad():
#      15     x = data.x
#
# TypeError: GCN.__init__() takes 1 positional argument but 4 were given

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN(data.num_features, 16, dataset.num_classes).to(device)
data = data.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.NLLLoss()

train_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(100):
    loss = train(model, data, optimizer, criterion, data.train_mask)
    train_acc = test(model, data, data.train_mask)
    val_acc = test(model, data, data.val_mask)

    train_losses.append(loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    print(f"Epoch {epoch+1}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

# Plot metrics
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label="Train Loss")
plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(val_accuracies, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.title("Training and Validation Metrics")
plt.legend()
plt.show()

# %%
def visualize_adjacency(edge_index, num_nodes):
    """
    Visualizes the adjacency matrix of the graph.
    """
    adj_matrix = torch.zeros((num_nodes, num_nodes))
    adj_matrix[edge_index[0], edge_index[1]] = 1
    adj_matrix += torch.eye(num_nodes)
    plt.figure(figsize=(8, 8))
    plt.imshow(adj_matrix.numpy(), cmap='Greys', interpolation='none')
    plt.title("Adjacency Matrix")
    plt.colorbar(label="Edge Presence")
    plt.xlabel("Node")
    plt.ylabel("Node")
    plt.show()

visualize_adjacency(data.edge_index, data.num_nodes)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

def visualize_embeddings(embeddings, labels, method='PCA', title='Node Embeddings'):
    """
    Visualize high-dimensional node embeddings using PCA or t-SNE.
    """
    if method == 'PCA':
        reducer = PCA(n_components=2)
    elif method == 't-SNE':
        reducer = TSNE(n_components=2, random_state=42)
    else:
        raise ValueError("Unsupported reduction method. Choose 'PCA' or 't-SNE'.")

    reduced_embeddings = reducer.fit_transform(embeddings)
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(
        reduced_embeddings[:, 0], reduced_embeddings[:, 1], 
        c=labels, cmap=plt.cm.rainbow, s=15
    )
    plt.colorbar(scatter, label="Node Labels")
    plt.title(title)
    plt.show()

# Forward pass to get node embeddings
model = GCN(data.num_features, 16, dataset.num_classes)
with torch.no_grad():
    embeddings1 = model.gcn1(data.x, data.edge_index)
    visualize_embeddings(embeddings1.numpy(), data.y.numpy(), method='t-SNE')

    embeddings2 = model.gcn2(embeddings1, data.edge_index)
    visualize_embeddings(embeddings2.numpy(), data.y.numpy(), method='t-SNE')

# %%
def visualize_parameters(model):
    for name, param in model.named_parameters():
        if param.requires_grad:
            plt.figure()
            plt.hist(param.detach().cpu().numpy().flatten(), bins=50)
            plt.title(f"Distribution of {name}")
            plt.xlabel("Value")
            plt.ylabel("Frequency")
            plt.show()

visualize_parameters(model)

# %%
# Save the trained model
torch.save(model.state_dict(), "gcn_model.pth")
print("Model saved to gcn_model.pth")

# %% [markdown]
# **Recreate the model architecture**
#
# model = GCN(data.num_features, 16, dataset.num_classes)
#
# model.load_state_dict(torch.load("gcn_model.pth"))
#
# model.eval()  # Set the model to evaluation mode
#
# print("Model loaded from gcn_model.pth")
